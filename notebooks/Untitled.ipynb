# %%
raw_files, articles = r'..\data\raw\\', []

with open(raw_files + 'article_lists.txt', 'r', encoding='utf-8') as f:
    article_lists = [line.strip() for line in f if line.strip()]

for article_list in article_lists:
    articles.extend()
